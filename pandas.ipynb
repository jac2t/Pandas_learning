# %%
import pandas as pd

# %%
df = pd.read_csv('nyc-weather.csv')

# %%
df
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 0        EWR  2013      1    1     0  37.04  21.92  53.97     230.0
# 1        EWR  2013      1    1     1  37.04  21.92  53.97     230.0
# 2        EWR  2013      1    1     2  37.94  21.92  52.09     230.0
# 3        EWR  2013      1    1     3  37.94  23.00  54.51     230.0
# 4        EWR  2013      1    1     4  37.94  24.08  57.04     240.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 26125    LGA  2013     12   30    19  35.96  19.94  51.78     340.0
# 26126    LGA  2013     12   30    20  33.98  17.06  49.51     330.0
# 26127    LGA  2013     12   30    21  32.00  15.08  49.19     340.0
# 26128    LGA  2013     12   30    22  30.92  12.92  46.74     320.0
# 26129    LGA  2013     12   30    23  28.94  10.94  46.41     330.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# ...

# %%
df['temp'].max()
# Out:
# 100.04

# %%
df['wind_speed'].mean()
# Out:
# 10.395868239751982

# %%
df.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib             time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01T00:00:00Z
# 1  15.891535     0.0    1013.0   10.0  2013-01-01T01:00:00Z
# 2  14.567241     0.0    1012.6   10.0  2013-01-01T02:00:00Z
# 3  15.891535     0.0    1012.7   10.0  2013-01-01T03:00:00Z
# 4  17.215830     0.0    1012.8   10.0  2013-01-01T04:00:00Z

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
df.describe()
# Out:
#           year         month           day          hour          temp  \
# count  26130.0  26130.000000  26130.000000  26130.000000  26129.000000
# mean    2013.0      6.505741     15.679717     11.518408     55.203515
# std        0.0      3.440031      8.765022      6.916581     17.782124
# min     2013.0      1.000000      1.000000      0.000000     10.940000
# 25%     2013.0      4.000000      8.000000      6.000000     39.920000
# 50%     2013.0      7.000000     16.000000     12.000000     55.040000
# 75%     2013.0      9.000000     23.000000     18.000000     69.980000
# max     2013.0     12.000000     31.000000     23.000000    100.040000
#
#                dewp         humid      wind_dir    wind_speed     wind_gust  \
# count  26129.000000  26129.000000  25712.000000  26127.000000  26127.000000
# mean      41.385399     62.347322    198.066661     10.395868     11.963357
# std       19.371649     19.196078    107.841624      8.521200      9.806027
# ...

# %%
df.tail(2)
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 26128    LGA  2013     12   30    22  30.92  12.92  46.74     320.0
# 26129    LGA  2013     12   30    23  28.94  10.94  46.41     330.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# 26128    17.26170  19.864419     0.0    1019.9   10.0  2013-12-30T22:00:00Z
# 26129    18.41248  21.188714     0.0    1020.9   10.0  2013-12-30T23:00:00Z

# %%
df[2:5]
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib             time_hour
# 2  14.567241     0.0    1012.6   10.0  2013-01-01T02:00:00Z
# 3  15.891535     0.0    1012.7   10.0  2013-01-01T03:00:00Z
# 4  17.215830     0.0    1012.8   10.0  2013-01-01T04:00:00Z

# %%
df.columns
# Out:
# Index(['origin', 'year', 'month', 'day', 'hour', 'temp', 'dewp', 'humid',
#        'wind_dir', 'wind_speed', 'wind_gust', 'precip', 'pressure', 'visib',
#        'time_hour'],
#       dtype='object')

# %%
df.dewp
# Out:
# 0        21.92
# 1        21.92
# 2        21.92
# 3        23.00
# 4        24.08
#          ...
# 26125    19.94
# 26126    17.06
# 26127    15.08
# 26128    12.92
# 26129    10.94
# Name: dewp, Length: 26130, dtype: float64

# %%
df['origin']
# Out:
# 0        EWR
# 1        EWR
# 2        EWR
# 3        EWR
# 4        EWR
#         ...
# 26125    LGA
# 26126    LGA
# 26127    LGA
# 26128    LGA
# 26129    LGA
# Name: origin, Length: 26130, dtype: object

# %%
df[["day","origin","precip"]]
# Out:
#        day origin  precip
# 0        1    EWR     0.0
# 1        1    EWR     0.0
# 2        1    EWR     0.0
# 3        1    EWR     0.0
# 4        1    EWR     0.0
# ...    ...    ...     ...
# 26125   30    LGA     0.0
# 26126   30    LGA     0.0
# 26127   30    LGA     0.0
# 26128   30    LGA     0.0
# 26129   30    LGA     0.0
#
# [26130 rows x 3 columns]

# %%
df["temp"].max()
# Out:
# 100.04

# %%
df["temp"].std()
# Out:
# 17.782123564058114

# %%
df["temp"].min()
# Out:
# 10.94

# %%
df["temp"].mean()
# Out:
# 55.20351486853688

# %%
## conditional selecting

# %%
df[df["temp"]>100]
# Out:
#      origin  year  month  day  hour    temp   dewp  humid  wind_dir  \
# 4764    EWR  2013      7   18    19  100.04  66.02  33.23     300.0
# 4789    EWR  2013      7   19    20  100.04  71.06  39.51     230.0
#
#       wind_speed  wind_gust  precip  pressure  visib             time_hour
# 4764     9.20624  10.594357     0.0    1015.0   10.0  2013-07-18T18:00:00Z
# 4789    20.71404  23.837303     0.0    1009.4   10.0  2013-07-19T19:00:00Z

# %%
df[['day','temp']][df.temp==df['temp'].max()]
# Out:
#       day    temp
# 4764   18  100.04
# 4789   19  100.04

# %% [markdown]
# Diiferent ways of creating dataframe:
# *   Using csv
# *   Using excel
# *   from python dictionary
# *   from list of tuples
# *   from list of dictionaries

# %%
import pandas as pd

df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/6_handling_missing_data_replace/weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df = pd.read_excel("weather_data.xlsx","Sheet1")
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %% [markdown]
# Using dictionary

# %%
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}

df=pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# Using tuples list

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# Using list of dictionaries

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
## id needed, we can skip some rows at the top: 
## read_csv("file.csv",skiprows=1)
## read_csv("file.csv",header=1) if both case, we skip one rows at the top

# %%
## if there is no header: 
## read_csv("file.csv",header=None, names=["col1", "col2", ....])

# %%
##read_csv("file.csv",nrows=5) here it will read only 5 rows, excluding the header

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",na_values=["not available","n.a."])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
## just replaced "n.a." by NaN that pandas can recognize

# %% [markdown]
# revenue cannot be negative, but earning per share can be negative. how to convert revenue and not eps?

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/4_read_write_to_excel/stock_data.csv",
               na_values={
                   'eps':["not available","n.a."],
                   'revenue':["not available","n.a.",-1],
                   'people':["not available","n.a."]
               })
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.to_csv("new.csv")

# %%
df.to_csv("new2.csv",index=False)

# %%
df = pd.read_excel("stock_data.xlsx")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# Handleing missing data

# %%
## dropna / fillna /

# %%
import pandas as pd

df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/6_handling_missing_data_replace/weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/5_handling_missing_data_fillna_dropna_interpolate/weather_data.csv",
               parse_dates=["day"])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.set_index('day',inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
## we can replace all NaN by a value using fillna
new_df=df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({
    'temperature':0,
    'windspeed':0,
    'event':"no event"
})
new_df
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
## filling with 0 does not really make sense. we can carry forward the values from previous days

# %%
new_df = df.fillna(method="ffill") ## ffill for "forward fill"
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df = df.fillna(method="bfill") ## bfill for "back fill" 
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
## check fillna documentation for limit and other methods

# %% [markdown]
# Dealing with missing values using "Interpolate"

# %%
new_df=df.interpolate()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.interpolate(method="time") ## see result, it takes into account the distance between avaible date and missing date
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=1) # here we keep rows that have at least one valid value
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(thresh=2) # here we keep rows that have at least two valid value
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# if we want to create rows for missing dates>

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# we can the using one of the fillna method above to add missing data

# %% [markdown]
# Using the "replace" method to deal with missing data

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/6_handling_missing_data_replace/weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
import numpy as np

# %%
new_df=df.replace(-99999,np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
## we can also replace by column using a dictionary, like w edid for fillna

# %%
## we can also use regex in replace, if for exple the data contains units and we wnat to remove them (like 7 mph)

# %%
df = pd.DataFrame({
    'score': ['exceptional','average', 'good', 'poor', 'average', 'exceptional'],
    'student': ['rob', 'maya', 'parthiv', 'tom', 'julian', 'erica']
})
df
# Out:
#          score  student
# 0  exceptional      rob
# 1      average     maya
# 2         good  parthiv
# 3         poor      tom
# 4      average   julian
# 5  exceptional    erica

# %%
df.replace(['poor', 'average', 'good', 'exceptional'], [1,2,3,4])
# Out:
#    score  student
# 0      4      rob
# 1      2     maya
# 2      3  parthiv
# 3      1      tom
# 4      2   julian
# 5      4    erica

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/7_group_by/weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g=df.groupby('city')
g

# %%
## this command created an object where the key is the city and the value is the weather data for that city

# %%
for city, city_df in g:
  print(city)
  print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
## SELECT * from city_data GROUP BY city

# %%
g.max() ## we can get the max from each city
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline

# %%
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# concatenate many data frames

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)
df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %% [markdown]
# Adding keys to concat

# %%
df = pd.concat([india_weather, us_weather], keys=["india", "us"])
df
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc['india']
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
df.loc['us']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
temperature_df = pd.DataFrame({
    "city": ["douala","bafoussam","buea"],
    "temperature": [32,45,30],
}, index=[0,1,2])
temperature_df
# Out:
#         city  temperature
# 0     douala           32
# 1  bafoussam           45
# 2       buea           30

# %%
windspeed_df = pd.DataFrame({
    "city": ["buea","bafoussam"],
    "windspeed": [7,12],
}, index=[1,0])
windspeed_df
# Out:
#         city  windspeed
# 1       buea          7
# 0  bafoussam         12

# %%
df = pd.concat([temperature_df,windspeed_df],axis=1)
df
# Out:
#         city  temperature       city  windspeed
# 0     douala           32  bafoussam       12.0
# 1  bafoussam           45       buea        7.0
# 2       buea           30        NaN        NaN

# %%
## have to concat using series

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temperature_df,s],axis=1)
df
# Out:
#         city  temperature  event
# 0     douala           32  Humid
# 1  bafoussam           45    Dry
# 2       buea           30   Rain

# %% [markdown]
# #Merge

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3=pd.merge(df1,df2,on='city') #just like join in sql
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando","baltimore"],
    "temperature": [21,14,35,45],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           45

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","San francisco"],
    "humidity": [65,68,75],
})
df2
# Out:
#             city  humidity
# 0        chicago        65
# 1       new york        68
# 2  San francisco        75

# %%
df3=pd.merge(df1,df2,on='city') 
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
## here we're geting only the elements that are common between the two DF

# %%
df3=pd.merge(df1,df2,on='city',how='outer') ##using the union of DFs. outer join in sql
df3
# Out:
#             city  temperature  humidity
# 0       new york         21.0      68.0
# 1        chicago         14.0      65.0
# 2        orlando         35.0       NaN
# 3      baltimore         45.0       NaN
# 4  San francisco          NaN      75.0

# %%
df3=pd.merge(df1,df2,on='city',how='left') # left join
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           45       NaN

# %%
df3=pd.merge(df1,df2,on='city',how='right') # right join
df3
# Out:
#             city  temperature  humidity
# 0        chicago         14.0        65
# 1       new york         21.0        68
# 2  San francisco          NaN        75

# %%
df3=pd.merge(df1,df2,on='city',how='outer', indicator=True)
df3
# Out:
#             city  temperature  humidity      _merge
# 0       new york         21.0      68.0        both
# 1        chicago         14.0      65.0        both
# 2        orlando         35.0       NaN   left_only
# 3      baltimore         45.0       NaN   left_only
# 4  San francisco          NaN      75.0  right_only

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/7_group_by/weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
df.pivot(index='day',columns='city')
# Out:
#          temperature                windspeed                 event           \
# city          mumbai new york paris    mumbai new york paris mumbai new york
# day
# 1/1/2017          90       32    45         5        6    20  Sunny     Rain
# 1/2/2017          85       36    50        12        7    13    Fog    Sunny
# 1/3/2017          87       28    54        15       12     8    Fog     Snow
# 1/4/2017          92       33    42         5        7    10   Rain    Sunny
#
#
# city       paris
# day
# 1/1/2017   Sunny
# 1/2/2017  Cloudy
# 1/3/2017  Cloudy
# 1/4/2017  Cloudy

# %%
df.pivot(index='day',columns='city', values ='windspeed')
# Out:
# city      mumbai  new york  paris
# day
# 1/1/2017       5         6     20
# 1/2/2017      12         7     13
# 1/3/2017      15        12      8
# 1/4/2017       5         7     10

# %%
df=pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/pandas/10_pivot/weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
df.pivot_table(index='city',columns='date')
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0
